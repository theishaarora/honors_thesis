# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
from matplotlib.ticker import ScalarFormatter

# %%
import geopandas as gpd
dbf_file = gpd.read_file("/Users/ishaarora/Desktop/2022-04-01_performance_mobile_tiles/gps_mobile_tiles.dbf")

# %%
dbf_file
# Out:
#                   quadkey  avg_d_kbps  avg_u_kbps  avg_lat_ms  tests  devices  \
# 0        0322321121212131       26208       16375          29    191       99
# 1        0231131002110331      118681       21498          55      7        1
# 2        1231211312200031       29135        6459         122     21        9
# 3        1220101003001130       38054        9568          29     11        6
# 4        0231131313310233       23269        4392          22      1        1
# ...                   ...         ...         ...         ...    ...      ...
# 3989247  1231333010033010       10116        2561          84      1        1
# 3989248  1322102231211122       16061       27563          30      1        1
# 3989249  1202033131301220       10997        2071          20      1        1
# 3989250  1202122201131313        5934        5023          32      1        1
# 3989251  0231022020130010       15805         112          36      1        1
#
# ...

# %%
shp_file = gpd.read_file("/Users/ishaarora/Desktop/2022-04-01_performance_mobile_tiles/gps_mobile_tiles.shp")
shp_file
# Out:
#                   quadkey  avg_d_kbps  avg_u_kbps  avg_lat_ms  tests  devices  \
# 0        0322321121212131       26208       16375          29    191       99
# 1        0231131002110331      118681       21498          55      7        1
# 2        1231211312200031       29135        6459         122     21        9
# 3        1220101003001130       38054        9568          29     11        6
# 4        0231131313310233       23269        4392          22      1        1
# ...                   ...         ...         ...         ...    ...      ...
# 3989247  1231333010033010       10116        2561          84      1        1
# 3989248  1322102231211122       16061       27563          30      1        1
# 3989249  1202033131301220       10997        2071          20      1        1
# 3989250  1202122201131313        5934        5023          32      1        1
# 3989251  0231022020130010       15805         112          36      1        1
#
# ...
